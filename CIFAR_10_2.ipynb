# %% [markdown]
# <a href="https://colab.research.google.com/github/sumukherror404/-6Companies30days/blob/main/CIFAR_10_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#importing the required libraries
import torch
from torch import nn
from torch.utils.data import DataLoader
from torchvision import datasets
from torchvision.transforms import ToTensor
import matplotlib.pyplot as plt

# %%
#Loading the dataset into training and testing dataset
training_data = datasets.CIFAR10(
    root = "data",
    train = True,
    download = True,
    transform = ToTensor()
)
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to data/cifar-10-python.tar.gz
#   0%|          | 0/170498071 [00:00<?, ?it/s]
# Extracting data/cifar-10-python.tar.gz to data

# %%
testing_data = datasets.CIFAR10(
    root = "data",
    train = True,
    download = True,
    transform = ToTensor()
)
# Out:
# Files already downloaded and verified

# %%
#preparing the dataloaders
train_data = DataLoader(training_data, batch_size = 64, shuffle = True)
test_data = DataLoader(testing_data, batch_size = 64, shuffle = True)

# %%
class NeuralNetwork(nn.Module):
  def __init__(self):
    super(NeuralNetwork,self).__init__()
    self.flatten = nn.Flatten()
    self.layer1 = nn.Linear(32*32*3,512)
    self.layer2 = nn.Linear(512,100)
    self.layer3 = nn.Linear(100,10)
    self.activ = nn.ReLU()
    self.norma = nn.BatchNorm1d(512)
    self.norma2 = nn.BatchNorm1d(100)
    self.dropout = nn.Dropout(0.2)
  def forward(self,x):
    x = self.flatten(x)
    x = self.layer1(x)
    x = self.norma(x)
    x = self.activ(x)
    x = self.layer2(x)
    x = self.norma2(x)
    x = self.activ(x)
    x = self.layer3(x)
    return x

# %%
model = NeuralNetwork()
learning_rate = 1e-3

# %%
loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate)
def train_loop(dataloader, model, loss_fn, optimizer):
    size = len(dataloader.dataset)
    for batch, (X, y) in enumerate(dataloader):
        # Compute prediction and loss
        pred = model(X)
        loss = loss_fn(pred, y)

        # Backpropagation
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        if batch % 100 == 0:
            loss, current = loss.item(), batch * len(X)
            print(f"loss: {loss:>7f}  [{current:>5d}/{size:>5d}]")


def test_loop(dataloader, model, loss_fn):
    size = len(dataloader.dataset)
    num_batches = len(dataloader)
    test_loss, correct = 0, 0

    with torch.no_grad():
        for X, y in dataloader:
            pred = model(X)
            test_loss += loss_fn(pred, y).item()
            correct += (pred.argmax(1) == y).type(torch.float).sum().item()

    test_loss /= num_batches
    correct /= size
    print(f"Test Error: \n Accuracy: {(100*correct):>0.1f}%, Avg loss: {test_loss:>8f} \n")

# %%
loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate,weight_decay= 1e-4)

epochs = 15
for t in range(epochs):
    print(f"Epoch {t+1}\n-------------------------------")
    train_loop(train_data, model, loss_fn, optimizer)
    test_loop(test_data, model, loss_fn)
print("Done!")
# Out:
# Epoch 1
# -------------------------------
# loss: 0.970076  [    0/50000]
# loss: 1.204887  [ 6400/50000]
# loss: 1.360537  [12800/50000]
# loss: 1.342595  [19200/50000]
# loss: 1.462744  [25600/50000]
# loss: 1.202505  [32000/50000]
# loss: 1.170682  [38400/50000]
# loss: 1.060549  [44800/50000]
# Test Error:
#  Accuracy: 61.3%, Avg loss: 1.154172
#
# Epoch 2
# -------------------------------
# loss: 1.232399  [    0/50000]
# loss: 1.082537  [ 6400/50000]
# loss: 1.242080  [12800/50000]
# loss: 1.232321  [19200/50000]
# loss: 1.202019  [25600/50000]
# loss: 1.298172  [32000/50000]
# loss: 1.074012  [38400/50000]
# loss: 1.252682  [44800/50000]
# Test Error:
#  Accuracy: 61.8%, Avg loss: 1.135662
#
# Epoch 3
# -------------------------------
# loss: 1.107044  [    0/50000]
# loss: 1.105437  [ 6400/50000]
# loss: 0.956723  [12800/50000]
# loss: 1.175496  [19200/50000]
# loss: 1.003520  [25600/50000]
# loss: 0.991707  [32000/50000]
# loss: 1.136246  [38400/50000]
# loss: 1.004120  [44800/50000]
# Test Error:
#  Accuracy: 62.6%, Avg loss: 1.110371
#
# Epoch 4
# -------------------------------
# loss: 1.039033  [    0/50000]
# loss: 1.021119  [ 6400/50000]
# loss: 1.168614  [12800/50000]
# loss: 1.289022  [19200/50000]
# loss: 1.237345  [25600/50000]
# loss: 1.228465  [32000/50000]
# loss: 1.083144  [38400/50000]
# loss: 1.062516  [44800/50000]
# Test Error:
#  Accuracy: 64.0%, Avg loss: 1.081388
#
# Epoch 5
# -------------------------------
# loss: 1.079210  [    0/50000]
# loss: 1.165428  [ 6400/50000]
# loss: 1.205499  [12800/50000]
# loss: 0.964099  [19200/50000]
# loss: 0.913734  [25600/50000]
# loss: 0.937955  [32000/50000]
# loss: 1.091994  [38400/50000]
# loss: 1.024513  [44800/50000]
# Test Error:
#  Accuracy: 64.5%, Avg loss: 1.066503
#
# Epoch 6
# -------------------------------
# loss: 1.128885  [    0/50000]
# loss: 1.112632  [ 6400/50000]
# loss: 1.097931  [12800/50000]
# loss: 1.045754  [19200/50000]
# loss: 1.153894  [25600/50000]
# loss: 1.110185  [32000/50000]
# loss: 0.977068  [38400/50000]
# loss: 1.154604  [44800/50000]
# Test Error:
#  Accuracy: 64.5%, Avg loss: 1.063764
#
# Epoch 7
# -------------------------------
# loss: 1.063591  [    0/50000]
# loss: 1.099357  [ 6400/50000]
# loss: 0.780298  [12800/50000]
# loss: 1.042811  [19200/50000]
# loss: 1.018338  [25600/50000]
# loss: 1.080872  [32000/50000]
# loss: 0.979068  [38400/50000]
# loss: 0.949396  [44800/50000]
# Test Error:
#  Accuracy: 66.6%, Avg loss: 1.003906
#
# Epoch 8
# -------------------------------
# loss: 1.023312  [    0/50000]
# loss: 0.708926  [ 6400/50000]
# loss: 0.911897  [12800/50000]
# loss: 0.969775  [19200/50000]
# loss: 0.920087  [25600/50000]
# loss: 1.180485  [32000/50000]
# loss: 1.119171  [38400/50000]
# loss: 1.063307  [44800/50000]
# Test Error:
#  Accuracy: 67.0%, Avg loss: 0.996957
#
# Epoch 9
# -------------------------------
# loss: 0.911876  [    0/50000]
# loss: 0.934415  [ 6400/50000]
# loss: 1.026679  [12800/50000]
# loss: 0.967462  [19200/50000]
# loss: 1.008249  [25600/50000]
# loss: 1.037833  [32000/50000]
# loss: 0.975078  [38400/50000]
# loss: 1.094538  [44800/50000]
# Test Error:
#  Accuracy: 68.3%, Avg loss: 0.968507
#
# Epoch 10
# -------------------------------
# loss: 0.975696  [    0/50000]
# loss: 0.869147  [ 6400/50000]
# loss: 0.967795  [12800/50000]
# loss: 0.992332  [19200/50000]
# loss: 0.940455  [25600/50000]
# loss: 0.819522  [32000/50000]
# loss: 0.993678  [38400/50000]
# loss: 0.866145  [44800/50000]
# Test Error:
#  Accuracy: 67.6%, Avg loss: 0.971295
#
# Epoch 11
# -------------------------------
# loss: 1.003792  [    0/50000]
# loss: 1.056317  [ 6400/50000]
# loss: 1.120625  [12800/50000]
# loss: 0.922705  [19200/50000]
# loss: 1.099570  [25600/50000]
# loss: 0.860985  [32000/50000]
# loss: 1.058148  [38400/50000]
# loss: 0.914101  [44800/50000]
# Test Error:
#  Accuracy: 67.7%, Avg loss: 0.974699
#
# Epoch 12
# -------------------------------
# loss: 0.861324  [    0/50000]
# loss: 1.017001  [ 6400/50000]
# loss: 0.975329  [12800/50000]
# loss: 0.909048  [19200/50000]
# loss: 0.773279  [25600/50000]
# loss: 0.939889  [32000/50000]
# loss: 1.022375  [38400/50000]
# loss: 0.769700  [44800/50000]
# Test Error:
#  Accuracy: 71.3%, Avg loss: 0.898095
#
# Epoch 13
# -------------------------------
# loss: 1.160228  [    0/50000]
# loss: 0.866645  [ 6400/50000]
# loss: 0.995692  [12800/50000]
# loss: 1.078640  [19200/50000]
# loss: 1.044859  [25600/50000]
# loss: 1.098113  [32000/50000]
# loss: 0.910734  [38400/50000]
# loss: 0.980367  [44800/50000]
# Test Error:
#  Accuracy: 67.6%, Avg loss: 0.958455
#
# Epoch 14
# -------------------------------
# loss: 1.017422  [    0/50000]
# loss: 1.020123  [ 6400/50000]
# loss: 0.786492  [12800/50000]
# loss: 1.174982  [19200/50000]
# loss: 1.054457  [25600/50000]
# loss: 1.052619  [32000/50000]
# loss: 0.835444  [38400/50000]
# loss: 1.052582  [44800/50000]
# Test Error:
#  Accuracy: 71.9%, Avg loss: 0.865528
#
# Epoch 15
# -------------------------------
# loss: 0.782213  [    0/50000]
# loss: 1.133159  [ 6400/50000]
# loss: 0.891204  [12800/50000]
# loss: 0.886762  [19200/50000]
# loss: 0.813251  [25600/50000]
# loss: 0.855376  [32000/50000]
# loss: 0.744377  [38400/50000]
# loss: 0.783142  [44800/50000]
# Test Error:
#  Accuracy: 72.2%, Avg loss: 0.856744
#
# Done!
